# %%
import yfinance as yf
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.optim import Adam
from sklearn.model_selection import train_test_split
import torch
from torch_geometric.utils import dense_to_sparse
import networkx as nx
import matplotlib.pyplot as plt

# %%
start_date = '2015-01-01'
end_date = '2024-08-31'
tickers = ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'JPM', 'JNJ']

# %%
Apple = yf.download('AAPL', start=start_date, end=end_date, threads=False)
Microsoft = yf.download('MSFT', start=start_date, end=end_date, threads=False)
Amazon = yf.download('AMZN', start=start_date, end=end_date, threads=False)
Google = yf.download('GOOGL', start=start_date, end=end_date, threads=False)
Jonson = yf.download('JNJ', start=start_date, end=end_date, threads=False)
JPMorgan = yf.download('JPM', start=start_date, end=end_date, threads=False)

print(Apple.head())
print(Microsoft.head())
print(Amazon.head())
print(Google.head())
print(Jonson.head())
print(JPMorgan.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.347172  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.661272  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.663500  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  23.995314  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  24.917267  237458000
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  40.232857  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  39.862885  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  39.277809  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  39.776844  29114100
# 2015-01-08  46.750000  47.750000  46.720001  47.590000  40.946995  29645200
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2015-01-02  15.6290  15.7375  15.3480  15.4260    15.4260  55664000
# 2015-01-05  15.3505  15.4190  15.0425  15.1095    15.1095  55484000
# 2015-01-06  15.1120  15.1500  14.6190  14.7645    14.7645  70380000
# 2015-01-07  14.8750  15.0640  14.7665  14.9210    14.9210  52806000
# 2015-01-08  15.0160  15.1570  14.8055  15.0230    15.0230  61768000
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  26.629999  26.790001  26.393999  26.477501  26.412100  26480000
# 2015-01-05  26.357500  26.399500  25.887501  25.973000  25.908844  41182000
# 2015-01-06  26.025000  26.060499  25.277500  25.332001  25.269430  54456000
# 2015-01-07  25.547501  25.574499  25.182501  25.257500  25.195114  46918000
# 2015-01-08  25.075500  25.375000  24.750999  25.345501  25.282896  73054000
#                   Open        High         Low       Close  Adj Close   Volume
# Date
# 2015-01-02  105.050003  105.550003  104.129997  104.519997  79.947601  5753600
# 2015-01-05  104.480003  104.730003  103.680000  103.790001  79.389236  8079300
# 2015-01-06  104.339996  104.989998  102.940002  103.279999  78.999130  7428000
# 2015-01-07  103.910004  105.830002  103.809998  105.559998  80.743095  7931700
# 2015-01-08  106.059998  106.489998  105.750000  106.389999  81.377968  9916000
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  62.180000  62.959999  62.070000  62.490002  47.709965  12600000
# 2015-01-05  62.060001  62.279999  60.230000  60.549999  46.228813  20100600
# 2015-01-06  60.639999  60.750000  58.349998  58.980000  45.030136  29074100
# 2015-01-07  59.889999  59.889999  58.669998  59.070000  45.098862  23843200
# 2015-01-08  59.970001  60.900002  59.970001  60.389999  46.106659  16971100

# %%
tickers_name = [Apple,Microsoft,Amazon,Google,Jonson,JPMorgan]

# %%
print(Apple.isnull().sum())
print(Microsoft.isnull().sum())
print(Google.isnull().sum())
print(Amazon.isnull().sum())
print(Jonson.isnull().sum())
print(JPMorgan.isnull().sum())
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
Apple['AAPL_MA20'] = Apple['Adj Close'].rolling(window=20).mean()
Microsoft['MSFT_MA20'] = Microsoft['Adj Close'].rolling(window=20).mean()
Amazon['AMZN_MA20'] = Amazon['Adj Close'].rolling(window=20).mean()
Google['GOOGL_MA20'] = Google['Adj Close'].rolling(window=20).mean()
Jonson['JNJ_MA20'] = Jonson['Adj Close'].rolling(window=20).mean()
JPMorgan['JPM_MA20'] = JPMorgan['Adj Close'].rolling(window=20).mean()



# 50-day Moving Average
Apple['AAPL_MA50'] = Apple['Adj Close'].rolling(window=50).mean()
Microsoft['MSFT_MA50'] = Microsoft['Adj Close'].rolling(window=50).mean()
Amazon['AMZN_MA50'] = Amazon['Adj Close'].rolling(window=50).mean()
Google['GOOGL_MA50'] = Google['Adj Close'].rolling(window=50).mean()
Jonson['JNJ_MA50'] = Jonson['Adj Close'].rolling(window=50).mean()
JPMorgan['JPM_MA50'] = JPMorgan['Adj Close'].rolling(window=50).mean()

# %%
def compute_RSI(series, period=14):
    delta = series.diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=period).mean()
    avg_loss = loss.rolling(window=period).mean()
    RS = avg_gain / avg_loss
    RSI = 100 - (100 / (1 + RS))
    return RSI

Apple['AAPL_RSI14'] = compute_RSI(Apple['Adj Close'])
Microsoft['MSFT_RSI14'] = compute_RSI(Microsoft['Adj Close'])
Google['GOOGL_RSI14'] = compute_RSI(Google['Adj Close'])
Amazon['AMZN_RSI14'] = compute_RSI(Amazon['Adj Close'])
Jonson['JNJ_RSI14'] = compute_RSI(Jonson['Adj Close'])
JPMorgan['JPM_RSI14'] = compute_RSI(JPMorgan['Adj Close'])

# %%
def compute_MACD(series, span_short=12, span_long=26, span_signal=9):
    ema_short = series.ewm(span=span_short, adjust=False).mean()
    ema_long = series.ewm(span=span_long, adjust=False).mean()
    MACD = ema_short - ema_long
    signal = MACD.ewm(span=span_signal, adjust=False).mean()
    return MACD, signal

Apple['AAPL_MACD'], Apple['AAPL_MACD_Signal'] = compute_MACD(Apple['Adj Close'])
Microsoft['MSFT_MACD'], Microsoft['MSFT_MACD_Signal'] = compute_MACD(Microsoft['Adj Close'])
Amazon['AMZN_MACD'], Amazon['AMZN_MACD_Signal'] = compute_MACD(Amazon['Adj Close'])
Google['GOOGL_MACD'], Google['GOOGL_MACD_Signal'] = compute_MACD(Google['Adj Close'])
Jonson['JNJ_MACD'], Jonson['JNJ_MACD_Signal'] = compute_MACD(Jonson['Adj Close'])
JPMorgan['JPM_MACD'], JPMorgan['JPM_MACD_Signal'] = compute_MACD(JPMorgan['Adj Close'])

# %%
# Creating a 1-day lag feature
Apple['AAPL_Close_Lag1'] = Apple['Adj Close'].shift(1)
Microsoft['MSFT_Close_Lag1'] = Microsoft['Adj Close'].shift(1)
Amazon['AMZN_Close_Lag1'] = Amazon['Adj Close'].shift(1)
Google['GOOGL_Close_Lag1'] = Google['Adj Close'].shift(1)
Jonson['JNJ_Close_Lag1'] = Jonson['Adj Close'].shift(1)
JPMorgan['JPM_Close_Lag1'] = JPMorgan['Adj Close'].shift(1)

for lag in range(1, 6):
    Apple[f'AAPL_Close_Lag{lag}'] = Apple['Adj Close'].shift(lag)
    Microsoft[f'MSFT_Close_Lag{lag}'] = Microsoft['Adj Close'].shift(lag)
    Amazon[f'AMZN_Close_Lag{lag}'] = Amazon['Adj Close'].shift(lag)
    Google[f'GOOGL_Close_Lag{lag}'] = Google['Adj Close'].shift(lag)
    Jonson[f'JNJ_Close_Lag{lag}'] = Jonson['Adj Close'].shift(lag)
    JPMorgan[f'JPM_Close_Lag{lag}'] = JPMorgan['Adj Close'].shift(lag)

# %%
Apple.fillna({'AAPL_MA20':Apple['AAPL_MA20'].mean()}, inplace=True)
Microsoft.fillna({'MSFT_MA20':Microsoft['MSFT_MA20'].mean()}, inplace=True)
Amazon.fillna({'AMZN_MA20':Amazon['AMZN_MA20'].mean()}, inplace=True)
Google.fillna({'GOOGL_MA20':Google['GOOGL_MA20'].mean()}, inplace=True)
Jonson.fillna({'JNJ_MA20':Jonson['JNJ_MA20'].mean()}, inplace=True)
JPMorgan.fillna({'JPM_MA20':JPMorgan['JPM_MA20'].mean()}, inplace=True)
Apple.fillna({'AAPL_MA50':Apple['AAPL_MA50'].mean()}, inplace=True)
Microsoft.fillna({'MSFT_MA50':Microsoft['MSFT_MA50'].mean()}, inplace=True)
Amazon.fillna({'AMZN_MA50':Amazon['AMZN_MA50'].mean()}, inplace=True)
Google.fillna({'GOOGL_MA50':Google['GOOGL_MA50'].mean()}, inplace=True)
Jonson.fillna({'JNJ_MA50':Jonson['JNJ_MA50'].mean()}, inplace=True)
JPMorgan.fillna({'JPM_MA50':JPMorgan['JPM_MA50'].mean()}, inplace=True)
Apple.fillna({'AAPL_RSI14':Apple['AAPL_RSI14'].mean()}, inplace=True)
Microsoft.fillna({'MSFT_RSI14':Microsoft['MSFT_RSI14'].mean()}, inplace=True)
Amazon.fillna({'AMZN_RSI14':Amazon['AMZN_RSI14'].mean()}, inplace=True)
Google.fillna({'GOOGL_RSI14':Google['GOOGL_RSI14'].mean()}, inplace=True)
Jonson.fillna({'JNJ_RSI14':Jonson['JNJ_RSI14'].mean()}, inplace=True)
JPMorgan.fillna({'JPM_RSI14':JPMorgan['JPM_RSI14'].mean()}, inplace=True)
for lag in range(1, 6):
    Apple.fillna({f'AAPL_Close_Lag{lag}':Apple[f'AAPL_Close_Lag{lag}'].mean()}, inplace=True)
    Microsoft.fillna({f'MSFT_Close_Lag{lag}':Microsoft[f'MSFT_Close_Lag{lag}'].mean()}, inplace=True)
    Amazon.fillna({f'AMZN_Close_Lag{lag}':Amazon[f'AMZN_Close_Lag{lag}'].mean()}, inplace=True)
    Google.fillna({f'GOOGL_Close_Lag{lag}':Google[f'GOOGL_Close_Lag{lag}'].mean()}, inplace=True)
    Jonson.fillna({f'JNJ_Close_Lag{lag}':Jonson[f'JNJ_Close_Lag{lag}'].mean()}, inplace=True)
    JPMorgan.fillna({f'JPM_Close_Lag{lag}':JPMorgan[f'JPM_Close_Lag{lag}'].mean()}, inplace=True)

# %%
Apple.rename(columns={'Open': 'AAPL_Open', 'High': 'AAPL_High', 'Low': 'AAPL_Low', 'Close': 'AAPL_Close', 'Adj Close': 'AAPL_Adj Close', 'Volume': 'AAPL_Volume'}, inplace=True)
Microsoft.rename(columns={'Open': 'MSFT_Open', 'High': 'MSFT_High', 'Low': 'MSFT_Low', 'Close': 'MSFT_Close', 'Adj Close': 'MSFT_Adj Close', 'Volume': 'MSFT_Volume'}, inplace=True)
Amazon.rename(columns={'Open': 'AMZN_Open', 'High': 'AMZN_High', 'Low': 'AMZN_Low', 'Close': 'AMZN_Close', 'Adj Close': 'AMZN_Adj Close', 'Volume': 'AMZN_Volume'}, inplace=True)
Google.rename(columns={'Open': 'GOOGL_Open', 'High': 'GOOGL_High', 'Low': 'GOOGL_Low', 'Close': 'GOOGL_Close', 'Adj Close': 'GOOGL_Adj Close', 'Volume': 'GOOGL_Volume'}, inplace=True)
Jonson.rename(columns={'Open': 'JNJ_Open', 'High': 'JNJ_High', 'Low': 'JNJ_Low', 'Close': 'JNJ_Close', 'Adj Close': 'JNJ_Adj Close', 'Volume': 'JNJ_Volume'}, inplace=True)
JPMorgan.rename(columns={'Open': 'JPM_Open', 'High': 'JPM_High', 'Low': 'JPM_Low', 'Close': 'JPM_Close', 'Adj Close': 'JPM_Adj Close', 'Volume': 'JPM_Volume'}, inplace=True)

# %%
stocks = pd.concat([Apple,Microsoft,Amazon,Google,Jonson,JPMorgan],axis = 1)

# %%
# Concatenate all stocks' adjusted closing prices
stocks_prices = pd.concat([Apple['AAPL_Adj Close'], Microsoft['MSFT_Adj Close'], Amazon['AMZN_Adj Close'], 
                           Google['GOOGL_Adj Close'], Jonson['JNJ_Adj Close'], JPMorgan['JPM_Adj Close']], axis=1)

# Calculate the correlation matrix
correlation_matrix = stocks_prices.corr()

# Convert the correlation matrix into an adjacency matrix (thresholding for the edges)
threshold = 0.8  # You can adjust this threshold
adjacency_matrix = (correlation_matrix > threshold).astype(int)

# %%
features = stocks.drop('JNJ_Adj Close',axis = 1)

# %%
features.replace([float('inf'), -float('inf')], float('nan'), inplace=True)
features.fillna(0, inplace=True)

# %%
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
node_features = torch.tensor(features, dtype=torch.float)

# %%
# Convert adjacency matrix to a sparse format
adjacency_matrix_sparse = torch.tensor(adjacency_matrix.values, dtype=torch.float32)
edge_index, edge_attr = dense_to_sparse(adjacency_matrix_sparse)

# %%
# Assuming `adjacency_matrix` is a Pandas DataFrame created earlier
# Convert stock ticker names to labels for each node in the graph
tickers = ['AAPL', 'MSFT', 'AMZN', 'GOOGL', 'JNJ', 'JPM']

# Create a NetworkX graph from the adjacency matrix
G = nx.from_pandas_adjacency(adjacency_matrix)

# Relabel the nodes to use stock tickers instead of numbers
mapping = {i: tickers[i] for i in range(len(tickers))}
G = nx.relabel_nodes(G, mapping)

# Draw the graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, seed=70)  # Layout for visual spacing

# Draw nodes, edges, and labels
nx.draw_networkx_nodes(G, pos, node_size=100, node_color="skyblue")
nx.draw_networkx_edges(G, pos, width=2, alpha=0.8, edge_color="gray")
nx.draw_networkx_labels(G, pos, font_size=12, font_weight="bold")

plt.title("Graph of Stock Correlations")
plt.show()

# %%
class GNNModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# Assuming `stocks` is the DataFrame that contains your data, with columns like 'AAPL_Adj Close', 'MSFT_Adj Close', etc.
# Concatenate the adjusted close columns for all stocks to form the labels
labels = pd.DataFrame(stocks['JNJ_Adj Close'])

# %%
# node_features.shape
labels.shape
# Out:
# (2432, 1)

# %%
input_dim = node_features.shape[1]
hidden_dim = 64
output_dim = labels.shape[1]  # Adjust to match the number of output labels
model = GNNModel(input_dim, hidden_dim, output_dim)
criterion = nn.MSELoss()
optimizer = Adam(model.parameters(), lr=0.002)

# %%
# Convert `labels` DataFrame to NumPy array, then split the data
labels_array = labels.values  # Convert DataFrame to NumPy array

# Split data into training and validation sets
train_features, val_features, train_labels, val_labels = train_test_split(
    node_features, labels_array, test_size=0.2, random_state=False, shuffle=False
)

# Convert the train and validation sets to PyTorch tensors
train_features = torch.tensor(train_features, dtype=torch.float32)
val_features = torch.tensor(val_features, dtype=torch.float32)
train_labels = torch.tensor(train_labels, dtype=torch.float32)
val_labels = torch.tensor(val_labels, dtype=torch.float32)
# Out:
# C:\Users\akki1\AppData\Local\Temp\ipykernel_31856\1909275192.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_features = torch.tensor(train_features, dtype=torch.float32)
# C:\Users\akki1\AppData\Local\Temp\ipykernel_31856\1909275192.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_features = torch.tensor(val_features, dtype=torch.float32)

# %%
num_epochs = 1800
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Training phase
    model.train()
    optimizer.zero_grad()
    train_outputs = model(train_features)
    train_loss = criterion(train_outputs, train_labels)
    train_loss.backward()
    optimizer.step()
    train_losses.append(train_loss.item())

    # Validation phase
    model.eval()
    with torch.no_grad():
        val_outputs = model(val_features)
        val_loss = criterion(val_outputs, val_labels)
        val_losses.append(val_loss.item())

    print(f'Epoch {epoch+1}, Training Loss: {train_loss.item()}, Validation Loss: {val_loss.item()}')
# Out:
# Epoch 1, Training Loss: 14273.28515625, Validation Loss: 23803.71484375
# Epoch 2, Training Loss: 14225.751953125, Validation Loss: 23714.607421875
# Epoch 3, Training Loss: 14178.3388671875, Validation Loss: 23629.955078125
# Epoch 4, Training Loss: 14131.5703125, Validation Loss: 23545.7109375
# Epoch 5, Training Loss: 14085.4287109375, Validation Loss: 23459.47265625
# Epoch 6, Training Loss: 14039.361328125, Validation Loss: 23369.3203125
# Epoch 7, Training Loss: 13992.3974609375, Validation Loss: 23272.896484375
# Epoch 8, Training Loss: 13943.40625, Validation Loss: 23169.302734375
# Epoch 9, Training Loss: 13891.8017578125, Validation Loss: 23058.857421875
# Epoch 10, Training Loss: 13837.6494140625, Validation Loss: 22942.1328125
# Epoch 11, Training Loss: 13781.2158203125, Validation Loss: 22819.75
# Epoch 12, Training Loss: 13722.60546875, Validation Loss: 22692.248046875
# Epoch 13, Training Loss: 13661.65234375, Validation Loss: 22560.158203125
# Epoch 14, Training Loss: 13598.142578125, Validation Loss: 22423.759765625
# Epoch 15, Training Loss: 13531.927734375, Validation Loss: 22283.123046875
# Epoch 16, Training Loss: 13462.9619140625, Validation Loss: 22138.23046875
# Epoch 17, Training Loss: 13391.3544921875, Validation Loss: 21989.0078125
# Epoch 18, Training Loss: 13317.2197265625, Validation Loss: 21835.412109375
# Epoch 19, Training Loss: 13240.654296875, Validation Loss: 21677.177734375
# Epoch 20, Training Loss: 13161.6181640625, Validation Loss: 21514.03515625
# Epoch 21, Training Loss: 13079.9580078125, Validation Loss: 21345.48828125
# Epoch 22, Training Loss: 12995.4970703125, Validation Loss: 21171.08203125
# Epoch 23, Training Loss: 12908.0927734375, Validation Loss: 20990.505859375
# Epoch 24, Training Loss: 12817.654296875, Validation Loss: 20803.615234375
# Epoch 25, Training Loss: 12724.1728515625, Validation Loss: 20610.484375
# Epoch 26, Training Loss: 12627.654296875, Validation Loss: 20411.267578125
# Epoch 27, Training Loss: 12528.140625, Validation Loss: 20206.193359375
# Epoch 28, Training Loss: 12425.673828125, Validation Loss: 19995.4375
# Epoch 29, Training Loss: 12320.2802734375, Validation Loss: 19779.0
# Epoch 30, Training Loss: 12211.9619140625, Validation Loss: 19556.80859375
# Epoch 31, Training Loss: 12100.712890625, Validation Loss: 19328.78125
# Epoch 32, Training Loss: 11986.5458984375, Validation Loss: 19094.83203125
# Epoch 33, Training Loss: 11869.4794921875, Validation Loss: 18854.931640625
# Epoch 34, Training Loss: 11749.537109375, Validation Loss: 18609.11328125
# Epoch 35, Training Loss: 11626.7744140625, Validation Loss: 18357.494140625
# Epoch 36, Training Loss: 11501.248046875, Validation Loss: 18100.203125
# Epoch 37, Training Loss: 11373.0107421875, Validation Loss: 17837.41796875
# Epoch 38, Training Loss: 11242.1318359375, Validation Loss: 17569.34765625
# Epoch 39, Training Loss: 11108.681640625, Validation Loss: 17296.208984375
# Epoch 40, Training Loss: 10972.75, Validation Loss: 17018.26171875
# Epoch 41, Training Loss: 10834.4267578125, Validation Loss: 16735.775390625
# Epoch 42, Training Loss: 10693.8134765625, Validation Loss: 16449.056640625
# Epoch 43, Training Loss: 10551.0166015625, Validation Loss: 16158.4033203125
# Epoch 44, Training Loss: 10406.150390625, Validation Loss: 15864.1015625
# Epoch 45, Training Loss: 10259.3271484375, Validation Loss: 15566.4150390625
# Epoch 46, Training Loss: 10110.6708984375, Validation Loss: 15265.5986328125
# Epoch 47, Training Loss: 9960.31640625, Validation Loss: 14961.927734375
# Epoch 48, Training Loss: 9808.400390625, Validation Loss: 14655.6474609375
# Epoch 49, Training Loss: 9655.07421875, Validation Loss: 14347.0234375
# Epoch 50, Training Loss: 9500.4970703125, Validation Loss: 14036.318359375
# Epoch 51, Training Loss: 9344.8271484375, Validation Loss: 13723.80859375
# Epoch 52, Training Loss: 9188.232421875, Validation Loss: 13409.7919921875
# Epoch 53, Training Loss: 9030.880859375, Validation Loss: 13094.5927734375
# Epoch 54, Training Loss: 8872.9501953125, Validation Loss: 12778.5693359375
# Epoch 55, Training Loss: 8714.61328125, Validation Loss: 12462.0966796875
# Epoch 56, Training Loss: 8556.0546875, Validation Loss: 12145.5546875
# Epoch 57, Training Loss: 8397.4619140625, Validation Loss: 11829.3427734375
# Epoch 58, Training Loss: 8239.0263671875, Validation Loss: 11513.8681640625
# Epoch 59, Training Loss: 8080.94287109375, Validation Loss: 11199.552734375
# Epoch 60, Training Loss: 7923.40576171875, Validation Loss: 10886.810546875
# Epoch 61, Training Loss: 7766.61181640625, Validation Loss: 10576.0595703125
# Epoch 62, Training Loss: 7610.75927734375, Validation Loss: 10267.72265625
# Epoch 63, Training Loss: 7456.04541015625, Validation Loss: 9962.2236328125
# Epoch 64, Training Loss: 7302.66259765625, Validation Loss: 9659.9794921875
# Epoch 65, Training Loss: 7150.81005859375, Validation Loss: 9361.3994140625
# Epoch 66, Training Loss: 7000.677734375, Validation Loss: 9066.8916015625
# Epoch 67, Training Loss: 6852.46044921875, Validation Loss: 8776.8544921875
# Epoch 68, Training Loss: 6706.3408203125, Validation Loss: 8491.693359375
# Epoch 69, Training Loss: 6562.4970703125, Validation Loss: 8211.8056640625
# Epoch 70, Training Loss: 6421.1044921875, Validation Loss: 7937.5830078125
# Epoch 71, Training Loss: 6282.330078125, Validation Loss: 7669.41455078125
# Epoch 72, Training Loss: 6146.3291015625, Validation Loss: 7407.67578125
# Epoch 73, Training Loss: 6013.25048828125, Validation Loss: 7152.73583984375
# Epoch 74, Training Loss: 5883.23046875, Validation Loss: 6904.94580078125
# Epoch 75, Training Loss: 5756.39697265625, Validation Loss: 6664.650390625
# Epoch 76, Training Loss: 5632.8583984375, Validation Loss: 6432.18115234375
# Epoch 77, Training Loss: 5512.71875, Validation Loss: 6207.849609375
# Epoch 78, Training Loss: 5396.0654296875, Validation Loss: 5991.95458984375
# Epoch 79, Training Loss: 5282.9677734375, Validation Loss: 5784.7724609375
# Epoch 80, Training Loss: 5173.4833984375, Validation Loss: 5586.55712890625
# Epoch 81, Training Loss: 5067.65185546875, Validation Loss: 5397.5439453125
# Epoch 82, Training Loss: 4965.498046875, Validation Loss: 5217.9443359375
# Epoch 83, Training Loss: 4867.03125, Validation Loss: 5047.953125
# Epoch 84, Training Loss: 4772.24658203125, Validation Loss: 4887.759765625
# Epoch 85, Training Loss: 4681.1181640625, Validation Loss: 4737.5205078125
# Epoch 86, Training Loss: 4593.615234375, Validation Loss: 4597.4140625
# Epoch 87, Training Loss: 4509.6904296875, Validation Loss: 4467.5869140625
# Epoch 88, Training Loss: 4429.2841796875, Validation Loss: 4348.03076171875
# Epoch 89, Training Loss: 4352.31689453125, Validation Loss: 4238.744140625
# Epoch 90, Training Loss: 4278.7001953125, Validation Loss: 4139.72314453125
# Epoch 91, Training Loss: 4208.337890625, Validation Loss: 4050.941162109375
# Epoch 92, Training Loss: 4141.1220703125, Validation Loss: 3972.338134765625
# Epoch 93, Training Loss: 4076.935302734375, Validation Loss: 3903.826416015625
# Epoch 94, Training Loss: 4015.6591796875, Validation Loss: 3845.279052734375
# Epoch 95, Training Loss: 3957.168701171875, Validation Loss: 3796.545654296875
# Epoch 96, Training Loss: 3901.343017578125, Validation Loss: 3757.45263671875
# Epoch 97, Training Loss: 3848.054931640625, Validation Loss: 3727.775390625
# Epoch 98, Training Loss: 3797.175048828125, Validation Loss: 3707.270751953125
# Epoch 99, Training Loss: 3748.5869140625, Validation Loss: 3695.662109375
# Epoch 100, Training Loss: 3702.162841796875, Validation Loss: 3692.64501953125
# Epoch 101, Training Loss: 3657.779296875, Validation Loss: 3697.89501953125
# Epoch 102, Training Loss: 3615.330078125, Validation Loss: 3711.060302734375
# Epoch 103, Training Loss: 3574.71044921875, Validation Loss: 3731.7646484375
# Epoch 104, Training Loss: 3535.818359375, Validation Loss: 3759.60302734375
# Epoch 105, Training Loss: 3498.55078125, Validation Loss: 3794.149658203125
# Epoch 106, Training Loss: 3462.81396484375, Validation Loss: 3834.9638671875
# Epoch 107, Training Loss: 3428.52685546875, Validation Loss: 3881.589599609375
# Epoch 108, Training Loss: 3395.6103515625, Validation Loss: 3933.553955078125
# Epoch 109, Training Loss: 3363.99169921875, Validation Loss: 3990.376708984375
# Epoch 110, Training Loss: 3333.6044921875, Validation Loss: 4051.564697265625
# Epoch 111, Training Loss: 3304.375244140625, Validation Loss: 4116.623046875
# Epoch 112, Training Loss: 3276.235107421875, Validation Loss: 4185.048828125
# Epoch 113, Training Loss: 3249.12353515625, Validation Loss: 4256.34326171875
# Epoch 114, Training Loss: 3222.98974609375, Validation Loss: 4330.00732421875
# Epoch 115, Training Loss: 3197.779296875, Validation Loss: 4405.5498046875
# Epoch 116, Training Loss: 3173.439453125, Validation Loss: 4482.49365234375
# Epoch 117, Training Loss: 3149.9130859375, Validation Loss: 4560.36962890625
# Epoch 118, Training Loss: 3127.149169921875, Validation Loss: 4638.7216796875
# Epoch 119, Training Loss: 3105.106689453125, Validation Loss: 4717.10986328125
# Epoch 120, Training Loss: 3083.724609375, Validation Loss: 4795.11474609375
# Epoch 121, Training Loss: 3062.96044921875, Validation Loss: 4872.3388671875
# Epoch 122, Training Loss: 3042.76171875, Validation Loss: 4948.39892578125
# Epoch 123, Training Loss: 3023.0859375, Validation Loss: 5022.943359375
# Epoch 124, Training Loss: 3003.893798828125, Validation Loss: 5095.64892578125
# Epoch 125, Training Loss: 2985.1396484375, Validation Loss: 5166.2177734375
# Epoch 126, Training Loss: 2966.770751953125, Validation Loss: 5234.38037109375
# Epoch 127, Training Loss: 2948.741943359375, Validation Loss: 5299.8935546875
# Epoch 128, Training Loss: 2931.017333984375, Validation Loss: 5362.5458984375
# Epoch 129, Training Loss: 2913.5546875, Validation Loss: 5422.1513671875
# Epoch 130, Training Loss: 2896.322509765625, Validation Loss: 5478.56591796875
# Epoch 131, Training Loss: 2879.2822265625, Validation Loss: 5531.66748046875
# Epoch 132, Training Loss: 2862.40185546875, Validation Loss: 5581.35546875
# Epoch 133, Training Loss: 2845.6513671875, Validation Loss: 5627.55908203125
# Epoch 134, Training Loss: 2829.0029296875, Validation Loss: 5670.24609375
# Epoch 135, Training Loss: 2812.423095703125, Validation Loss: 5709.38720703125
# Epoch 136, Training Loss: 2795.886474609375, Validation Loss: 5744.984375
# Epoch 137, Training Loss: 2779.365966796875, Validation Loss: 5777.05859375
# Epoch 138, Training Loss: 2762.8408203125, Validation Loss: 5805.63916015625
# Epoch 139, Training Loss: 2746.2900390625, Validation Loss: 5830.7861328125
# Epoch 140, Training Loss: 2729.702392578125, Validation Loss: 5852.57275390625
# Epoch 141, Training Loss: 2713.0615234375, Validation Loss: 5871.08837890625
# Epoch 142, Training Loss: 2696.362060546875, Validation Loss: 5886.4521484375
# Epoch 143, Training Loss: 2679.59033203125, Validation Loss: 5898.775390625
# Epoch 144, Training Loss: 2662.736083984375, Validation Loss: 5908.18408203125
# Epoch 145, Training Loss: 2645.789306640625, Validation Loss: 5914.80078125
# Epoch 146, Training Loss: 2628.744140625, Validation Loss: 5918.74658203125
# Epoch 147, Training Loss: 2611.592041015625, Validation Loss: 5920.150390625
# Epoch 148, Training Loss: 2594.335205078125, Validation Loss: 5919.16796875
# Epoch 149, Training Loss: 2576.9716796875, Validation Loss: 5915.9287109375
# Epoch 150, Training Loss: 2559.492919921875, Validation Loss: 5910.580078125
# Epoch 151, Training Loss: 2541.898681640625, Validation Loss: 5903.25244140625
# Epoch 152, Training Loss: 2524.18603515625, Validation Loss: 5894.07080078125
# Epoch 153, Training Loss: 2506.346435546875, Validation Loss: 5883.16552734375
# Epoch 154, Training Loss: 2488.38330078125, Validation Loss: 5870.68408203125
# Epoch 155, Training Loss: 2470.29833984375, Validation Loss: 5856.7724609375
# Epoch 156, Training Loss: 2452.09228515625, Validation Loss: 5841.5537109375
# Epoch 157, Training Loss: 2433.763916015625, Validation Loss: 5825.15087890625
# Epoch 158, Training Loss: 2415.311767578125, Validation Loss: 5807.64697265625
# Epoch 159, Training Loss: 2396.736572265625, Validation Loss: 5789.12353515625
# Epoch 160, Training Loss: 2378.04296875, Validation Loss: 5769.73095703125
# Epoch 161, Training Loss: 2359.228271484375, Validation Loss: 5749.54052734375
# Epoch 162, Training Loss: 2340.294677734375, Validation Loss: 5728.62841796875
# Epoch 163, Training Loss: 2321.24072265625, Validation Loss: 5707.080078125
# Epoch 164, Training Loss: 2302.064697265625, Validation Loss: 5684.9765625
# Epoch 165, Training Loss: 2282.77099609375, Validation Loss: 5662.4208984375
# Epoch 166, Training Loss: 2263.365478515625, Validation Loss: 5639.41845703125
# Epoch 167, Training Loss: 2243.850830078125, Validation Loss: 5616.06591796875
# Epoch 168, Training Loss: 2224.2255859375, Validation Loss: 5592.4404296875
# Epoch 169, Training Loss: 2204.488037109375, Validation Loss: 5568.67138671875
# Epoch 170, Training Loss: 2184.649658203125, Validation Loss: 5544.833984375
# Epoch 171, Training Loss: 2164.70166015625, Validation Loss: 5520.8896484375
# Epoch 172, Training Loss: 2144.6513671875, Validation Loss: 5496.96923828125
# Epoch 173, Training Loss: 2124.503662109375, Validation Loss: 5473.12353515625
# Epoch 174, Training Loss: 2104.267578125, Validation Loss: 5449.42724609375
# Epoch 175, Training Loss: 2083.94873046875, Validation Loss: 5425.7626953125
# Epoch 176, Training Loss: 2063.559326171875, Validation Loss: 5402.21630859375
# Epoch 177, Training Loss: 2043.08837890625, Validation Loss: 5378.78759765625
# Epoch 178, Training Loss: 2022.5517578125, Validation Loss: 5355.48779296875
# Epoch 179, Training Loss: 2001.93896484375, Validation Loss: 5332.45361328125
# Epoch 180, Training Loss: 1981.2646484375, Validation Loss: 5309.708984375
# Epoch 181, Training Loss: 1960.5462646484375, Validation Loss: 5287.14599609375
# Epoch 182, Training Loss: 1939.7830810546875, Validation Loss: 5264.8994140625
# Epoch 183, Training Loss: 1918.9830322265625, Validation Loss: 5242.9970703125
# Epoch 184, Training Loss: 1898.1668701171875, Validation Loss: 5221.50830078125
# Epoch 185, Training Loss: 1877.345703125, Validation Loss: 5200.4892578125
# Epoch 186, Training Loss: 1856.524169921875, Validation Loss: 5179.87451171875
# Epoch 187, Training Loss: 1835.7161865234375, Validation Loss: 5159.65869140625
# Epoch 188, Training Loss: 1814.9393310546875, Validation Loss: 5139.76318359375
# Epoch 189, Training Loss: 1794.18359375, Validation Loss: 5120.24169921875
# Epoch 190, Training Loss: 1773.4461669921875, Validation Loss: 5100.978515625
# Epoch 191, Training Loss: 1752.7347412109375, Validation Loss: 5081.98291015625
# Epoch 192, Training Loss: 1732.05859375, Validation Loss: 5063.2431640625
# Epoch 193, Training Loss: 1711.4202880859375, Validation Loss: 5044.7353515625
# Epoch 194, Training Loss: 1690.8228759765625, Validation Loss: 5026.439453125
# Epoch 195, Training Loss: 1670.267822265625, Validation Loss: 5008.3662109375
# Epoch 196, Training Loss: 1649.7645263671875, Validation Loss: 4990.48583984375
# Epoch 197, Training Loss: 1629.316650390625, Validation Loss: 4972.7734375
# Epoch 198, Training Loss: 1608.931640625, Validation Loss: 4955.17138671875
# Epoch 199, Training Loss: 1588.6190185546875, Validation Loss: 4937.66015625
# Epoch 200, Training Loss: 1568.384033203125, Validation Loss: 4920.1962890625
# Epoch 201, Training Loss: 1548.2357177734375, Validation Loss: 4902.74267578125
# Epoch 202, Training Loss: 1528.1795654296875, Validation Loss: 4885.31689453125
# Epoch 203, Training Loss: 1508.2264404296875, Validation Loss: 4867.91455078125
# Epoch 204, Training Loss: 1488.38037109375, Validation Loss: 4850.515625
# Epoch 205, Training Loss: 1468.646728515625, Validation Loss: 4833.10791015625
# Epoch 206, Training Loss: 1449.033203125, Validation Loss: 4815.693359375
# Epoch 207, Training Loss: 1429.5447998046875, Validation Loss: 4798.2646484375
# Epoch 208, Training Loss: 1410.1915283203125, Validation Loss: 4780.81201171875
# Epoch 209, Training Loss: 1390.9739990234375, Validation Loss: 4763.330078125
# Epoch 210, Training Loss: 1371.9005126953125, Validation Loss: 4745.7998046875
# Epoch 211, Training Loss: 1352.9771728515625, Validation Loss: 4728.2158203125
# Epoch 212, Training Loss: 1334.2139892578125, Validation Loss: 4710.5771484375
# Epoch 213, Training Loss: 1315.6180419921875, Validation Loss: 4692.88525390625
# Epoch 214, Training Loss: 1297.19384765625, Validation Loss: 4675.14453125
# Epoch 215, Training Loss: 1278.94970703125, Validation Loss: 4657.35302734375
# Epoch 216, Training Loss: 1260.8902587890625, Validation Loss: 4639.525390625
# Epoch 217, Training Loss: 1243.0166015625, Validation Loss: 4621.65380859375
# Epoch 218, Training Loss: 1225.3359375, Validation Loss: 4603.73876953125
# Epoch 219, Training Loss: 1207.85107421875, Validation Loss: 4585.78125
# Epoch 220, Training Loss: 1190.5653076171875, Validation Loss: 4567.79638671875
# Epoch 221, Training Loss: 1173.4849853515625, Validation Loss: 4549.78662109375
# Epoch 222, Training Loss: 1156.6123046875, Validation Loss: 4531.74609375
# Epoch 223, Training Loss: 1139.9517822265625, Validation Loss: 4513.7001953125
# Epoch 224, Training Loss: 1123.5045166015625, Validation Loss: 4495.64013671875
# Epoch 225, Training Loss: 1107.2744140625, Validation Loss: 4477.5654296875
# Epoch 226, Training Loss: 1091.2618408203125, Validation Loss: 4459.498046875
# Epoch 227, Training Loss: 1075.4674072265625, Validation Loss: 4441.4345703125
# Epoch 228, Training Loss: 1059.8946533203125, Validation Loss: 4423.3916015625
# Epoch 229, Training Loss: 1044.5447998046875, Validation Loss: 4405.37451171875
# Epoch 230, Training Loss: 1029.4217529296875, Validation Loss: 4387.38037109375
# Epoch 231, Training Loss: 1014.5299072265625, Validation Loss: 4369.40966796875
# Epoch 232, Training Loss: 999.87060546875, Validation Loss: 4351.46630859375
# Epoch 233, Training Loss: 985.44580078125, Validation Loss: 4333.5546875
# Epoch 234, Training Loss: 971.25341796875, Validation Loss: 4315.681640625
# Epoch 235, Training Loss: 957.2940673828125, Validation Loss: 4297.8525390625
# Epoch 236, Training Loss: 943.5677490234375, Validation Loss: 4280.068359375
# Epoch 237, Training Loss: 930.0703125, Validation Loss: 4262.326171875
# Epoch 238, Training Loss: 916.8029174804688, Validation Loss: 4244.62744140625
# Epoch 239, Training Loss: 903.7671508789062, Validation Loss: 4226.9765625
# Epoch 240, Training Loss: 890.9600219726562, Validation Loss: 4209.37548828125
# Epoch 241, Training Loss: 878.3803100585938, Validation Loss: 4191.82470703125
# Epoch 242, Training Loss: 866.0272216796875, Validation Loss: 4174.3349609375
# Epoch 243, Training Loss: 853.9004516601562, Validation Loss: 4156.9013671875
# Epoch 244, Training Loss: 841.998291015625, Validation Loss: 4139.52978515625
# Epoch 245, Training Loss: 830.3192749023438, Validation Loss: 4122.2265625
# Epoch 246, Training Loss: 818.8599853515625, Validation Loss: 4104.99267578125
# Epoch 247, Training Loss: 807.6177978515625, Validation Loss: 4087.829345703125
# Epoch 248, Training Loss: 796.5914306640625, Validation Loss: 4070.73876953125
# Epoch 249, Training Loss: 785.7796630859375, Validation Loss: 4053.72607421875
# Epoch 250, Training Loss: 775.181640625, Validation Loss: 4036.796875
# Epoch 251, Training Loss: 764.7931518554688, Validation Loss: 4019.954345703125
# Epoch 252, Training Loss: 754.610107421875, Validation Loss: 4003.1962890625
# Epoch 253, Training Loss: 744.628662109375, Validation Loss: 3986.525146484375
# Epoch 254, Training Loss: 734.8462524414062, Validation Loss: 3969.939453125
# Epoch 255, Training Loss: 725.2577514648438, Validation Loss: 3953.443115234375
# Epoch 256, Training Loss: 715.860595703125, Validation Loss: 3937.033935546875
# Epoch 257, Training Loss: 706.6517333984375, Validation Loss: 3920.715087890625
# Epoch 258, Training Loss: 697.6294555664062, Validation Loss: 3904.48779296875
# Epoch 259, Training Loss: 688.7892456054688, Validation Loss: 3888.35791015625
# Epoch 260, Training Loss: 680.124755859375, Validation Loss: 3872.315673828125
# Epoch 261, Training Loss: 671.63671875, Validation Loss: 3856.3603515625
# Epoch 262, Training Loss: 663.321044921875, Validation Loss: 3840.494140625
# Epoch 263, Training Loss: 655.1741943359375, Validation Loss: 3824.73193359375
# Epoch 264, Training Loss: 647.1917724609375, Validation Loss: 3809.08154296875
# Epoch 265, Training Loss: 639.37060546875, Validation Loss: 3793.5205078125
# Epoch 266, Training Loss: 631.7064819335938, Validation Loss: 3778.044677734375
# Epoch 267, Training Loss: 624.1953125, Validation Loss: 3762.671630859375
# Epoch 268, Training Loss: 616.8340454101562, Validation Loss: 3747.38232421875
# Epoch 269, Training Loss: 609.6180419921875, Validation Loss: 3732.175048828125
# Epoch 270, Training Loss: 602.544189453125, Validation Loss: 3717.05029296875
# Epoch 271, Training Loss: 595.6097412109375, Validation Loss: 3702.014404296875
# Epoch 272, Training Loss: 588.812255859375, Validation Loss: 3687.05859375
# Epoch 273, Training Loss: 582.1478881835938, Validation Loss: 3672.187255859375
# Epoch 274, Training Loss: 575.6141357421875, Validation Loss: 3657.40185546875
# Epoch 275, Training Loss: 569.2059326171875, Validation Loss: 3642.701171875
# Epoch 276, Training Loss: 562.9191284179688, Validation Loss: 3628.083984375
# Epoch 277, Training Loss: 556.7550048828125, Validation Loss: 3613.55908203125
# Epoch 278, Training Loss: 550.7091064453125, Validation Loss: 3599.1220703125
# Epoch 279, Training Loss: 544.775390625, Validation Loss: 3584.759521484375
# Epoch 280, Training Loss: 538.9534301757812, Validation Loss: 3570.494384765625
# Epoch 281, Training Loss: 533.2418212890625, Validation Loss: 3556.317626953125
# Epoch 282, Training Loss: 527.6361083984375, Validation Loss: 3542.2197265625
# Epoch 283, Training Loss: 522.1346435546875, Validation Loss: 3528.223876953125
# Epoch 284, Training Loss: 516.7317504882812, Validation Loss: 3514.3095703125
# Epoch 285, Training Loss: 511.427001953125, Validation Loss: 3500.473876953125
# Epoch 286, Training Loss: 506.21575927734375, Validation Loss: 3486.72607421875
# Epoch 287, Training Loss: 501.0959167480469, Validation Loss: 3473.053955078125
# Epoch 288, Training Loss: 496.0644836425781, Validation Loss: 3459.499755859375
# Epoch 289, Training Loss: 491.1202087402344, Validation Loss: 3446.06201171875
# Epoch 290, Training Loss: 486.26104736328125, Validation Loss: 3432.723388671875
# Epoch 291, Training Loss: 481.4847717285156, Validation Loss: 3419.478515625
# Epoch 292, Training Loss: 476.78985595703125, Validation Loss: 3406.338623046875
# Epoch 293, Training Loss: 472.174072265625, Validation Loss: 3393.281005859375
# Epoch 294, Training Loss: 467.6355285644531, Validation Loss: 3380.31689453125
# Epoch 295, Training Loss: 463.1705322265625, Validation Loss: 3367.403076171875
# Epoch 296, Training Loss: 458.77630615234375, Validation Loss: 3354.570556640625
# Epoch 297, Training Loss: 454.4532470703125, Validation Loss: 3341.82373046875
# Epoch 298, Training Loss: 450.19915771484375, Validation Loss: 3329.16162109375
# Epoch 299, Training Loss: 446.0127868652344, Validation Loss: 3316.57958984375
# Epoch 300, Training Loss: 441.89520263671875, Validation Loss: 3304.093017578125
# Epoch 301, Training Loss: 437.84234619140625, Validation Loss: 3291.664794921875
# Epoch 302, Training Loss: 433.8509826660156, Validation Loss: 3279.311767578125
# Epoch 303, Training Loss: 429.9192810058594, Validation Loss: 3267.074462890625
# Epoch 304, Training Loss: 426.04693603515625, Validation Loss: 3254.93212890625
# Epoch 305, Training Loss: 422.2321472167969, Validation Loss: 3242.8779296875
# Epoch 306, Training Loss: 418.4728698730469, Validation Loss: 3230.893310546875
# Epoch 307, Training Loss: 414.77056884765625, Validation Loss: 3218.999755859375
# Epoch 308, Training Loss: 411.1258239746094, Validation Loss: 3207.19482421875
# Epoch 309, Training Loss: 407.53558349609375, Validation Loss: 3195.486572265625
# Epoch 310, Training Loss: 403.997802734375, Validation Loss: 3183.864990234375
# Epoch 311, Training Loss: 400.5124206542969, Validation Loss: 3172.30126953125
# Epoch 312, Training Loss: 397.0783386230469, Validation Loss: 3160.79296875
# Epoch 313, Training Loss: 393.69207763671875, Validation Loss: 3149.348388671875
# Epoch 314, Training Loss: 390.3527526855469, Validation Loss: 3137.98046875
# Epoch 315, Training Loss: 387.0602111816406, Validation Loss: 3126.6787109375
# Epoch 316, Training Loss: 383.8127746582031, Validation Loss: 3115.46533203125
# Epoch 317, Training Loss: 380.6094970703125, Validation Loss: 3104.3583984375
# Epoch 318, Training Loss: 377.45001220703125, Validation Loss: 3093.351806640625
# Epoch 319, Training Loss: 374.33367919921875, Validation Loss: 3082.43603515625
# Epoch 320, Training Loss: 371.2572326660156, Validation Loss: 3071.5849609375
# Epoch 321, Training Loss: 368.2212219238281, Validation Loss: 3060.804931640625
# Epoch 322, Training Loss: 365.2246398925781, Validation Loss: 3050.119384765625
# Epoch 323, Training Loss: 362.2663269042969, Validation Loss: 3039.54541015625
# Epoch 324, Training Loss: 359.34637451171875, Validation Loss: 3029.0712890625
# Epoch 325, Training Loss: 356.46636962890625, Validation Loss: 3018.703369140625
# Epoch 326, Training Loss: 353.6230163574219, Validation Loss: 3008.445556640625
# Epoch 327, Training Loss: 350.8149108886719, Validation Loss: 2998.27587890625
# Epoch 328, Training Loss: 348.0431823730469, Validation Loss: 2988.179443359375
# Epoch 329, Training Loss: 345.30560302734375, Validation Loss: 2978.153076171875
# Epoch 330, Training Loss: 342.6025695800781, Validation Loss: 2968.23046875
# Epoch 331, Training Loss: 339.934814453125, Validation Loss: 2958.423095703125
# Epoch 332, Training Loss: 337.3003234863281, Validation Loss: 2948.709716796875
# Epoch 333, Training Loss: 334.6982727050781, Validation Loss: 2939.09130859375
# Epoch 334, Training Loss: 332.1282043457031, Validation Loss: 2929.56103515625
# Epoch 335, Training Loss: 329.5883483886719, Validation Loss: 2920.10986328125
# Epoch 336, Training Loss: 327.0782165527344, Validation Loss: 2910.75390625
# Epoch 337, Training Loss: 324.59759521484375, Validation Loss: 2901.48486328125
# Epoch 338, Training Loss: 322.145751953125, Validation Loss: 2892.3203125
# Epoch 339, Training Loss: 319.7219543457031, Validation Loss: 2883.28515625
# Epoch 340, Training Loss: 317.32659912109375, Validation Loss: 2874.3505859375
# Epoch 341, Training Loss: 314.95977783203125, Validation Loss: 2865.501953125
# Epoch 342, Training Loss: 312.6207275390625, Validation Loss: 2856.762939453125
# Epoch 343, Training Loss: 310.30859375, Validation Loss: 2848.14208984375
# Epoch 344, Training Loss: 308.0230407714844, Validation Loss: 2839.634521484375
# Epoch 345, Training Loss: 305.76385498046875, Validation Loss: 2831.21630859375
# Epoch 346, Training Loss: 303.5292663574219, Validation Loss: 2822.873046875
# Epoch 347, Training Loss: 301.3207702636719, Validation Loss: 2814.606201171875
# Epoch 348, Training Loss: 299.1382141113281, Validation Loss: 2806.4208984375
# Epoch 349, Training Loss: 296.9808654785156, Validation Loss: 2798.3115234375
# Epoch 350, Training Loss: 294.84759521484375, Validation Loss: 2790.275146484375
# Epoch 351, Training Loss: 292.73785400390625, Validation Loss: 2782.317626953125
# Epoch 352, Training Loss: 290.6518249511719, Validation Loss: 2774.43310546875
# Epoch 353, Training Loss: 288.5893859863281, Validation Loss: 2766.64111328125
# Epoch 354, Training Loss: 286.55023193359375, Validation Loss: 2758.925537109375
# Epoch 355, Training Loss: 284.5338134765625, Validation Loss: 2751.286865234375
# Epoch 356, Training Loss: 282.5400695800781, Validation Loss: 2743.7265625
# Epoch 357, Training Loss: 280.568115234375, Validation Loss: 2736.223388671875
# Epoch 358, Training Loss: 278.61676025390625, Validation Loss: 2728.79736328125
# Epoch 359, Training Loss: 276.6863708496094, Validation Loss: 2721.434326171875
# Epoch 360, Training Loss: 274.7785949707031, Validation Loss: 2714.133056640625
# Epoch 361, Training Loss: 272.8924560546875, Validation Loss: 2706.893798828125
# Epoch 362, Training Loss: 271.02740478515625, Validation Loss: 2699.703125
# Epoch 363, Training Loss: 269.18157958984375, Validation Loss: 2692.562255859375
# Epoch 364, Training Loss: 267.355712890625, Validation Loss: 2685.467041015625
# Epoch 365, Training Loss: 265.5494079589844, Validation Loss: 2678.4140625
# Epoch 366, Training Loss: 263.7630310058594, Validation Loss: 2671.40576171875
# Epoch 367, Training Loss: 261.9959411621094, Validation Loss: 2664.449951171875
# Epoch 368, Training Loss: 260.24798583984375, Validation Loss: 2657.5400390625
# Epoch 369, Training Loss: 258.5183410644531, Validation Loss: 2650.66455078125
# Epoch 370, Training Loss: 256.80548095703125, Validation Loss: 2643.844970703125
# Epoch 371, Training Loss: 255.11045837402344, Validation Loss: 2637.068359375
# Epoch 372, Training Loss: 253.43283081054688, Validation Loss: 2630.32666015625
# Epoch 373, Training Loss: 251.77227783203125, Validation Loss: 2623.634521484375
# Epoch 374, Training Loss: 250.12759399414062, Validation Loss: 2616.983642578125
# Epoch 375, Training Loss: 248.49935913085938, Validation Loss: 2610.37548828125
# Epoch 376, Training Loss: 246.8876953125, Validation Loss: 2603.816162109375
# Epoch 377, Training Loss: 245.29164123535156, Validation Loss: 2597.2998046875
# Epoch 378, Training Loss: 243.71173095703125, Validation Loss: 2590.815673828125
# Epoch 379, Training Loss: 242.1478729248047, Validation Loss: 2584.364990234375
# Epoch 380, Training Loss: 240.6005096435547, Validation Loss: 2577.94580078125
# Epoch 381, Training Loss: 239.06814575195312, Validation Loss: 2571.565185546875
# Epoch 382, Training Loss: 237.55154418945312, Validation Loss: 2565.224853515625
# Epoch 383, Training Loss: 236.05038452148438, Validation Loss: 2558.92041015625
# Epoch 384, Training Loss: 234.56427001953125, Validation Loss: 2552.63427734375
# Epoch 385, Training Loss: 233.0928955078125, Validation Loss: 2546.379150390625
# Epoch 386, Training Loss: 231.63543701171875, Validation Loss: 2540.163818359375
# Epoch 387, Training Loss: 230.1916046142578, Validation Loss: 2533.997802734375
# Epoch 388, Training Loss: 228.76092529296875, Validation Loss: 2527.876953125
# Epoch 389, Training Loss: 227.3438262939453, Validation Loss: 2521.7978515625
# Epoch 390, Training Loss: 225.93997192382812, Validation Loss: 2515.7578125
# Epoch 391, Training Loss: 224.549560546875, Validation Loss: 2509.75732421875
# Epoch 392, Training Loss: 223.1713409423828, Validation Loss: 2503.804443359375
# Epoch 393, Training Loss: 221.80551147460938, Validation Loss: 2497.89404296875
# Epoch 394, Training Loss: 220.45199584960938, Validation Loss: 2492.02783203125
# Epoch 395, Training Loss: 219.11102294921875, Validation Loss: 2486.205322265625
# Epoch 396, Training Loss: 217.7825469970703, Validation Loss: 2480.41796875
# Epoch 397, Training Loss: 216.46629333496094, Validation Loss: 2474.67041015625
# Epoch 398, Training Loss: 215.16275024414062, Validation Loss: 2468.9609375
# Epoch 399, Training Loss: 213.87103271484375, Validation Loss: 2463.28564453125
# Epoch 400, Training Loss: 212.5909423828125, Validation Loss: 2457.643798828125
# Epoch 401, Training Loss: 211.32203674316406, Validation Loss: 2452.0380859375
# Epoch 402, Training Loss: 210.0650634765625, Validation Loss: 2446.465087890625
# Epoch 403, Training Loss: 208.8194580078125, Validation Loss: 2440.92822265625
# Epoch 404, Training Loss: 207.5852813720703, Validation Loss: 2435.41943359375
# Epoch 405, Training Loss: 206.3624725341797, Validation Loss: 2429.927734375
# Epoch 406, Training Loss: 205.1501007080078, Validation Loss: 2424.46435546875
# Epoch 407, Training Loss: 203.9481964111328, Validation Loss: 2419.03271484375
# Epoch 408, Training Loss: 202.75787353515625, Validation Loss: 2413.628662109375
# Epoch 409, Training Loss: 201.57810974121094, Validation Loss: 2408.252685546875
# Epoch 410, Training Loss: 200.4088897705078, Validation Loss: 2402.90380859375
# Epoch 411, Training Loss: 199.251220703125, Validation Loss: 2397.57958984375
# Epoch 412, Training Loss: 198.10462951660156, Validation Loss: 2392.280029296875
# Epoch 413, Training Loss: 196.96827697753906, Validation Loss: 2387.008544921875
# Epoch 414, Training Loss: 195.84210205078125, Validation Loss: 2381.7578125
# Epoch 415, Training Loss: 194.72610473632812, Validation Loss: 2376.534912109375
# Epoch 416, Training Loss: 193.6204376220703, Validation Loss: 2371.34130859375
# Epoch 417, Training Loss: 192.524169921875, Validation Loss: 2366.176025390625
# Epoch 418, Training Loss: 191.43722534179688, Validation Loss: 2361.0322265625
# Epoch 419, Training Loss: 190.35995483398438, Validation Loss: 2355.912841796875
# Epoch 420, Training Loss: 189.2925262451172, Validation Loss: 2350.816162109375
# Epoch 421, Training Loss: 188.23458862304688, Validation Loss: 2345.744384765625
# Epoch 422, Training Loss: 187.1861572265625, Validation Loss: 2340.69384765625
# Epoch 423, Training Loss: 186.14678955078125, Validation Loss: 2335.66796875
# Epoch 424, Training Loss: 185.1161651611328, Validation Loss: 2330.66650390625
# Epoch 425, Training Loss: 184.0935821533203, Validation Loss: 2325.69189453125
# Epoch 426, Training Loss: 183.07972717285156, Validation Loss: 2320.746826171875
# Epoch 427, Training Loss: 182.07493591308594, Validation Loss: 2315.823974609375
# Epoch 428, Training Loss: 181.07823181152344, Validation Loss: 2310.927734375
# Epoch 429, Training Loss: 180.09022521972656, Validation Loss: 2306.057373046875
# Epoch 430, Training Loss: 179.11097717285156, Validation Loss: 2301.21435546875
# Epoch 431, Training Loss: 178.13992309570312, Validation Loss: 2296.3984375
# Epoch 432, Training Loss: 177.17706298828125, Validation Loss: 2291.6064453125
# Epoch 433, Training Loss: 176.22251892089844, Validation Loss: 2286.8388671875
# Epoch 434, Training Loss: 175.27615356445312, Validation Loss: 2282.092041015625
# Epoch 435, Training Loss: 174.33775329589844, Validation Loss: 2277.371337890625
# Epoch 436, Training Loss: 173.4075469970703, Validation Loss: 2272.673095703125
# Epoch 437, Training Loss: 172.48533630371094, Validation Loss: 2267.996826171875
# Epoch 438, Training Loss: 171.57107543945312, Validation Loss: 2263.343994140625
# Epoch 439, Training Loss: 170.66416931152344, Validation Loss: 2258.715087890625
# Epoch 440, Training Loss: 169.76486206054688, Validation Loss: 2254.109619140625
# Epoch 441, Training Loss: 168.87306213378906, Validation Loss: 2249.530029296875
# Epoch 442, Training Loss: 167.988525390625, Validation Loss: 2244.97705078125
# Epoch 443, Training Loss: 167.11183166503906, Validation Loss: 2240.449951171875
# Epoch 444, Training Loss: 166.2420196533203, Validation Loss: 2235.945556640625
# Epoch 445, Training Loss: 165.3798370361328, Validation Loss: 2231.463623046875
# Epoch 446, Training Loss: 164.52516174316406, Validation Loss: 2227.001220703125
# Epoch 447, Training Loss: 163.6771697998047, Validation Loss: 2222.557861328125
# Epoch 448, Training Loss: 162.83624267578125, Validation Loss: 2218.131591796875
# Epoch 449, Training Loss: 162.00216674804688, Validation Loss: 2213.72119140625
# Epoch 450, Training Loss: 161.17474365234375, Validation Loss: 2209.32763671875
# Epoch 451, Training Loss: 160.3539581298828, Validation Loss: 2204.94873046875
# Epoch 452, Training Loss: 159.53981018066406, Validation Loss: 2200.57861328125
# Epoch 453, Training Loss: 158.73074340820312, Validation Loss: 2196.224609375
# Epoch 454, Training Loss: 157.92770385742188, Validation Loss: 2191.889404296875
# Epoch 455, Training Loss: 157.13075256347656, Validation Loss: 2187.57177734375
# Epoch 456, Training Loss: 156.3397216796875, Validation Loss: 2183.276123046875
# Epoch 457, Training Loss: 155.55465698242188, Validation Loss: 2179.000244140625
# Epoch 458, Training Loss: 154.7755126953125, Validation Loss: 2174.74169921875
# Epoch 459, Training Loss: 154.0027618408203, Validation Loss: 2170.4951171875
# Epoch 460, Training Loss: 153.23646545410156, Validation Loss: 2166.256591796875
# Epoch 461, Training Loss: 152.47625732421875, Validation Loss: 2162.0302734375
# Epoch 462, Training Loss: 151.72177124023438, Validation Loss: 2157.813720703125
# Epoch 463, Training Loss: 150.97280883789062, Validation Loss: 2153.613037109375
# Epoch 464, Training Loss: 150.22962951660156, Validation Loss: 2149.433349609375
# Epoch 465, Training Loss: 149.49191284179688, Validation Loss: 2145.271484375
# Epoch 466, Training Loss: 148.75962829589844, Validation Loss: 2141.1357421875
# Epoch 467, Training Loss: 148.03350830078125, Validation Loss: 2137.015869140625
# Epoch 468, Training Loss: 147.3136444091797, Validation Loss: 2132.909423828125
# Epoch 469, Training Loss: 146.5991973876953, Validation Loss: 2128.817138671875
# Epoch 470, Training Loss: 145.89019775390625, Validation Loss: 2124.731201171875
# Epoch 471, Training Loss: 145.18646240234375, Validation Loss: 2120.66259765625
# Epoch 472, Training Loss: 144.48814392089844, Validation Loss: 2116.606201171875
# Epoch 473, Training Loss: 143.79591369628906, Validation Loss: 2112.565673828125
# Epoch 474, Training Loss: 143.1094207763672, Validation Loss: 2108.541748046875
# Epoch 475, Training Loss: 142.428466796875, Validation Loss: 2104.53466796875
# Epoch 476, Training Loss: 141.75289916992188, Validation Loss: 2100.5419921875
# Epoch 477, Training Loss: 141.08230590820312, Validation Loss: 2096.56494140625
# Epoch 478, Training Loss: 140.4165802001953, Validation Loss: 2092.605712890625
# Epoch 479, Training Loss: 139.7557373046875, Validation Loss: 2088.6650390625
# Epoch 480, Training Loss: 139.10000610351562, Validation Loss: 2084.741943359375
# Epoch 481, Training Loss: 138.44883728027344, Validation Loss: 2080.8310546875
# Epoch 482, Training Loss: 137.80223083496094, Validation Loss: 2076.933349609375
# Epoch 483, Training Loss: 137.16006469726562, Validation Loss: 2073.052978515625
# Epoch 484, Training Loss: 136.52252197265625, Validation Loss: 2069.187744140625
# Epoch 485, Training Loss: 135.88998413085938, Validation Loss: 2065.34130859375
# Epoch 486, Training Loss: 135.2622528076172, Validation Loss: 2061.50634765625
# Epoch 487, Training Loss: 134.63946533203125, Validation Loss: 2057.688720703125
# Epoch 488, Training Loss: 134.02117919921875, Validation Loss: 2053.887939453125
# Epoch 489, Training Loss: 133.4072723388672, Validation Loss: 2050.1044921875
# Epoch 490, Training Loss: 132.79806518554688, Validation Loss: 2046.3377685546875
# Epoch 491, Training Loss: 132.19374084472656, Validation Loss: 2042.58544921875
# Epoch 492, Training Loss: 131.5933837890625, Validation Loss: 2038.84326171875
# Epoch 493, Training Loss: 130.99728393554688, Validation Loss: 2035.1185302734375
# Epoch 494, Training Loss: 130.40550231933594, Validation Loss: 2031.4078369140625
# Epoch 495, Training Loss: 129.8185272216797, Validation Loss: 2027.7080078125
# Epoch 496, Training Loss: 129.2360076904297, Validation Loss: 2024.0225830078125
# Epoch 497, Training Loss: 128.65826416015625, Validation Loss: 2020.3502197265625
# Epoch 498, Training Loss: 128.08482360839844, Validation Loss: 2016.6934814453125
# Epoch 499, Training Loss: 127.51573944091797, Validation Loss: 2013.054443359375
# Epoch 500, Training Loss: 126.95018005371094, Validation Loss: 2009.43359375
# Epoch 501, Training Loss: 126.38896179199219, Validation Loss: 2005.825439453125
# Epoch 502, Training Loss: 125.83216094970703, Validation Loss: 2002.2301025390625
# Epoch 503, Training Loss: 125.279541015625, Validation Loss: 1998.650390625
# Epoch 504, Training Loss: 124.7306900024414, Validation Loss: 1995.086181640625
# Epoch 505, Training Loss: 124.18586730957031, Validation Loss: 1991.53662109375
# Epoch 506, Training Loss: 123.6449203491211, Validation Loss: 1987.999755859375
# Epoch 507, Training Loss: 123.1075668334961, Validation Loss: 1984.480224609375
# Epoch 508, Training Loss: 122.57405853271484, Validation Loss: 1980.9774169921875
# Epoch 509, Training Loss: 122.04422760009766, Validation Loss: 1977.491455078125
# Epoch 510, Training Loss: 121.51807403564453, Validation Loss: 1974.0223388671875
# Epoch 511, Training Loss: 120.9954833984375, Validation Loss: 1970.5679931640625
# Epoch 512, Training Loss: 120.47664642333984, Validation Loss: 1967.1295166015625
# Epoch 513, Training Loss: 119.9612808227539, Validation Loss: 1963.707763671875
# Epoch 514, Training Loss: 119.4493408203125, Validation Loss: 1960.30078125
# Epoch 515, Training Loss: 118.94055938720703, Validation Loss: 1956.91064453125
# Epoch 516, Training Loss: 118.43535614013672, Validation Loss: 1953.5369873046875
# Epoch 517, Training Loss: 117.93357849121094, Validation Loss: 1950.1781005859375
# Epoch 518, Training Loss: 117.43536376953125, Validation Loss: 1946.8343505859375
# Epoch 519, Training Loss: 116.9407730102539, Validation Loss: 1943.5068359375
# Epoch 520, Training Loss: 116.44943237304688, Validation Loss: 1940.194580078125
# Epoch 521, Training Loss: 115.9609146118164, Validation Loss: 1936.8984375
# Epoch 522, Training Loss: 115.47542572021484, Validation Loss: 1933.6180419921875
# Epoch 523, Training Loss: 114.99248504638672, Validation Loss: 1930.353515625
# Epoch 524, Training Loss: 114.51233673095703, Validation Loss: 1927.0999755859375
# Epoch 525, Training Loss: 114.03497314453125, Validation Loss: 1923.856689453125
# Epoch 526, Training Loss: 113.56057739257812, Validation Loss: 1920.6239013671875
# Epoch 527, Training Loss: 113.08966827392578, Validation Loss: 1917.4017333984375
# Epoch 528, Training Loss: 112.6220703125, Validation Loss: 1914.1939697265625
# Epoch 529, Training Loss: 112.1580581665039, Validation Loss: 1910.999755859375
# Epoch 530, Training Loss: 111.69741821289062, Validation Loss: 1907.8182373046875
# Epoch 531, Training Loss: 111.24012756347656, Validation Loss: 1904.651123046875
# Epoch 532, Training Loss: 110.78583526611328, Validation Loss: 1901.4971923828125
# Epoch 533, Training Loss: 110.33419036865234, Validation Loss: 1898.354248046875
# Epoch 534, Training Loss: 109.88459014892578, Validation Loss: 1895.224609375
# Epoch 535, Training Loss: 109.4378433227539, Validation Loss: 1892.1083984375
# Epoch 536, Training Loss: 108.99398803710938, Validation Loss: 1889.004150390625
# Epoch 537, Training Loss: 108.55299377441406, Validation Loss: 1885.9117431640625
# Epoch 538, Training Loss: 108.11446380615234, Validation Loss: 1882.83349609375
# Epoch 539, Training Loss: 107.67866516113281, Validation Loss: 1879.767333984375
# Epoch 540, Training Loss: 107.2457275390625, Validation Loss: 1876.713623046875
# Epoch 541, Training Loss: 106.81576538085938, Validation Loss: 1873.6689453125
# Epoch 542, Training Loss: 106.38821411132812, Validation Loss: 1870.633056640625
# Epoch 543, Training Loss: 105.9635009765625, Validation Loss: 1867.6063232421875
# Epoch 544, Training Loss: 105.54145050048828, Validation Loss: 1864.58984375
# Epoch 545, Training Loss: 105.12191772460938, Validation Loss: 1861.5767822265625
# Epoch 546, Training Loss: 104.70494079589844, Validation Loss: 1858.5731201171875
# Epoch 547, Training Loss: 104.29039001464844, Validation Loss: 1855.58056640625
# Epoch 548, Training Loss: 103.87874603271484, Validation Loss: 1852.6007080078125
# Epoch 549, Training Loss: 103.46981811523438, Validation Loss: 1849.62939453125
# Epoch 550, Training Loss: 103.06343841552734, Validation Loss: 1846.6689453125
# Epoch 551, Training Loss: 102.65946960449219, Validation Loss: 1843.719482421875
# Epoch 552, Training Loss: 102.25839233398438, Validation Loss: 1840.7781982421875
# Epoch 553, Training Loss: 101.86002349853516, Validation Loss: 1837.846923828125
# Epoch 554, Training Loss: 101.46415710449219, Validation Loss: 1834.9271240234375
# Epoch 555, Training Loss: 101.07079315185547, Validation Loss: 1832.01953125
# Epoch 556, Training Loss: 100.67990112304688, Validation Loss: 1829.12255859375
# Epoch 557, Training Loss: 100.29154205322266, Validation Loss: 1826.236572265625
# Epoch 558, Training Loss: 99.90521240234375, Validation Loss: 1823.3626708984375
# Epoch 559, Training Loss: 99.52120971679688, Validation Loss: 1820.5006103515625
# Epoch 560, Training Loss: 99.13963317871094, Validation Loss: 1817.6513671875
# Epoch 561, Training Loss: 98.76041412353516, Validation Loss: 1814.8140869140625
# Epoch 562, Training Loss: 98.38375854492188, Validation Loss: 1811.9864501953125
# Epoch 563, Training Loss: 98.00960540771484, Validation Loss: 1809.1678466796875
# Epoch 564, Training Loss: 97.63823699951172, Validation Loss: 1806.3603515625
# Epoch 565, Training Loss: 97.2693862915039, Validation Loss: 1803.563232421875
# Epoch 566, Training Loss: 96.90298461914062, Validation Loss: 1800.77685546875
# Epoch 567, Training Loss: 96.5394515991211, Validation Loss: 1797.998291015625
# Epoch 568, Training Loss: 96.17821502685547, Validation Loss: 1795.22900390625
# Epoch 569, Training Loss: 95.81939697265625, Validation Loss: 1792.4713134765625
# Epoch 570, Training Loss: 95.46281433105469, Validation Loss: 1789.7257080078125
# Epoch 571, Training Loss: 95.10844421386719, Validation Loss: 1786.99169921875
# Epoch 572, Training Loss: 94.75630950927734, Validation Loss: 1784.2664794921875
# Epoch 573, Training Loss: 94.40638732910156, Validation Loss: 1781.5518798828125
# Epoch 574, Training Loss: 94.05863952636719, Validation Loss: 1778.8477783203125
# Epoch 575, Training Loss: 93.71305084228516, Validation Loss: 1776.149658203125
# Epoch 576, Training Loss: 93.36964416503906, Validation Loss: 1773.4630126953125
# Epoch 577, Training Loss: 93.02828216552734, Validation Loss: 1770.7889404296875
# Epoch 578, Training Loss: 92.68861389160156, Validation Loss: 1768.1229248046875
# Epoch 579, Training Loss: 92.3509292602539, Validation Loss: 1765.4683837890625
# Epoch 580, Training Loss: 92.01517486572266, Validation Loss: 1762.825439453125
# Epoch 581, Training Loss: 91.68142700195312, Validation Loss: 1760.1966552734375
# Epoch 582, Training Loss: 91.34967803955078, Validation Loss: 1757.57958984375
# Epoch 583, Training Loss: 91.01990509033203, Validation Loss: 1754.9730224609375
# Epoch 584, Training Loss: 90.69225311279297, Validation Loss: 1752.3775634765625
# Epoch 585, Training Loss: 90.366455078125, Validation Loss: 1749.790771484375
# Epoch 586, Training Loss: 90.04222106933594, Validation Loss: 1747.2125244140625
# Epoch 587, Training Loss: 89.7198715209961, Validation Loss: 1744.6446533203125
# Epoch 588, Training Loss: 89.39958190917969, Validation Loss: 1742.0872802734375
# Epoch 589, Training Loss: 89.08177185058594, Validation Loss: 1739.53955078125
# Epoch 590, Training Loss: 88.76576232910156, Validation Loss: 1737.000732421875
# Epoch 591, Training Loss: 88.45130920410156, Validation Loss: 1734.4727783203125
# Epoch 592, Training Loss: 88.1390151977539, Validation Loss: 1731.95556640625
# Epoch 593, Training Loss: 87.82881164550781, Validation Loss: 1729.4451904296875
# Epoch 594, Training Loss: 87.52033996582031, Validation Loss: 1726.9423828125
# Epoch 595, Training Loss: 87.21383666992188, Validation Loss: 1724.4517822265625
# Epoch 596, Training Loss: 86.90880584716797, Validation Loss: 1721.973388671875
# Epoch 597, Training Loss: 86.6055908203125, Validation Loss: 1719.5074462890625
# Epoch 598, Training Loss: 86.30437469482422, Validation Loss: 1717.05224609375
# Epoch 599, Training Loss: 86.0051498413086, Validation Loss: 1714.6051025390625
# Epoch 600, Training Loss: 85.70781707763672, Validation Loss: 1712.1690673828125
# Epoch 601, Training Loss: 85.41234588623047, Validation Loss: 1709.74365234375
# Epoch 602, Training Loss: 85.1187744140625, Validation Loss: 1707.3282470703125
# Epoch 603, Training Loss: 84.82691192626953, Validation Loss: 1704.9146728515625
# Epoch 604, Training Loss: 84.53662872314453, Validation Loss: 1702.50537109375
# Epoch 605, Training Loss: 84.24816131591797, Validation Loss: 1700.103271484375
# Epoch 606, Training Loss: 83.96150207519531, Validation Loss: 1697.707275390625
# Epoch 607, Training Loss: 83.676513671875, Validation Loss: 1695.3177490234375
# Epoch 608, Training Loss: 83.39318084716797, Validation Loss: 1692.9346923828125
# Epoch 609, Training Loss: 83.11140441894531, Validation Loss: 1690.5557861328125
# Epoch 610, Training Loss: 82.83126831054688, Validation Loss: 1688.181396484375
# Epoch 611, Training Loss: 82.552734375, Validation Loss: 1685.8101806640625
# Epoch 612, Training Loss: 82.27583312988281, Validation Loss: 1683.4432373046875
# Epoch 613, Training Loss: 82.00045776367188, Validation Loss: 1681.0833740234375
# ...
# Epoch 1604, Training Loss: 18.7753849029541, Validation Loss: 835.1845092773438
# Epoch 1605, Training Loss: 18.758331298828125, Validation Loss: 835.1058349609375
# Epoch 1606, Training Loss: 18.74120330810547, Validation Loss: 835.0296020507812
# Epoch 1607, Training Loss: 18.723941802978516, Validation Loss: 834.95458984375
# Epoch 1608, Training Loss: 18.706619262695312, Validation Loss: 834.8770141601562
# Epoch 1609, Training Loss: 18.689239501953125, Validation Loss: 834.8016967773438
# Epoch 1610, Training Loss: 18.67185401916504, Validation Loss: 834.7294921875
# Epoch 1611, Training Loss: 18.65447235107422, Validation Loss: 834.6605224609375
# Epoch 1612, Training Loss: 18.637075424194336, Validation Loss: 834.5973510742188
# Epoch 1613, Training Loss: 18.61968421936035, Validation Loss: 834.5415649414062
# Epoch 1614, Training Loss: 18.602285385131836, Validation Loss: 834.4943237304688
# Epoch 1615, Training Loss: 18.584888458251953, Validation Loss: 834.451171875
# Epoch 1616, Training Loss: 18.567453384399414, Validation Loss: 834.4111938476562
# Epoch 1617, Training Loss: 18.549945831298828, Validation Loss: 834.3742065429688
# Epoch 1618, Training Loss: 18.532400131225586, Validation Loss: 834.339599609375
# Epoch 1619, Training Loss: 18.514820098876953, Validation Loss: 834.3104248046875
# Epoch 1620, Training Loss: 18.497220993041992, Validation Loss: 834.28515625
# Epoch 1621, Training Loss: 18.47960662841797, Validation Loss: 834.2640380859375
# Epoch 1622, Training Loss: 18.461938858032227, Validation Loss: 834.2463989257812
# Epoch 1623, Training Loss: 18.44426727294922, Validation Loss: 834.22705078125
# Epoch 1624, Training Loss: 18.42647361755371, Validation Loss: 834.2114868164062
# Epoch 1625, Training Loss: 18.408435821533203, Validation Loss: 834.1953125
# Epoch 1626, Training Loss: 18.39042091369629, Validation Loss: 834.1815795898438
# Epoch 1627, Training Loss: 18.372257232666016, Validation Loss: 834.177734375
# Epoch 1628, Training Loss: 18.35400390625, Validation Loss: 834.1758422851562
# Epoch 1629, Training Loss: 18.335634231567383, Validation Loss: 834.1721801757812
# Epoch 1630, Training Loss: 18.317331314086914, Validation Loss: 834.1636352539062
# Epoch 1631, Training Loss: 18.29896354675293, Validation Loss: 834.1600952148438
# Epoch 1632, Training Loss: 18.280426025390625, Validation Loss: 834.16162109375
# Epoch 1633, Training Loss: 18.261655807495117, Validation Loss: 834.1657104492188
# Epoch 1634, Training Loss: 18.242746353149414, Validation Loss: 834.1715698242188
# Epoch 1635, Training Loss: 18.223800659179688, Validation Loss: 834.1764526367188
# Epoch 1636, Training Loss: 18.204832077026367, Validation Loss: 834.1834106445312
# Epoch 1637, Training Loss: 18.18570899963379, Validation Loss: 834.1947021484375
# Epoch 1638, Training Loss: 18.16659927368164, Validation Loss: 834.2109985351562
# Epoch 1639, Training Loss: 18.147510528564453, Validation Loss: 834.2285766601562
# Epoch 1640, Training Loss: 18.128440856933594, Validation Loss: 834.2471923828125
# Epoch 1641, Training Loss: 18.109512329101562, Validation Loss: 834.269287109375
# Epoch 1642, Training Loss: 18.09052085876465, Validation Loss: 834.2900390625
# Epoch 1643, Training Loss: 18.07155990600586, Validation Loss: 834.308837890625
# Epoch 1644, Training Loss: 18.052671432495117, Validation Loss: 834.3223876953125
# Epoch 1645, Training Loss: 18.03369140625, Validation Loss: 834.332763671875
# Epoch 1646, Training Loss: 18.014528274536133, Validation Loss: 834.3363037109375
# Epoch 1647, Training Loss: 17.99541664123535, Validation Loss: 834.3372192382812
# Epoch 1648, Training Loss: 17.976346969604492, Validation Loss: 834.3357543945312
# Epoch 1649, Training Loss: 17.957399368286133, Validation Loss: 834.3306884765625
# Epoch 1650, Training Loss: 17.93876075744629, Validation Loss: 834.3208618164062
# Epoch 1651, Training Loss: 17.92030906677246, Validation Loss: 834.3073120117188
# Epoch 1652, Training Loss: 17.90191650390625, Validation Loss: 834.2887573242188
# Epoch 1653, Training Loss: 17.883625030517578, Validation Loss: 834.271240234375
# Epoch 1654, Training Loss: 17.86545181274414, Validation Loss: 834.2479858398438
# Epoch 1655, Training Loss: 17.847389221191406, Validation Loss: 834.2217407226562
# Epoch 1656, Training Loss: 17.82944107055664, Validation Loss: 834.1942138671875
# Epoch 1657, Training Loss: 17.811519622802734, Validation Loss: 834.1630249023438
# Epoch 1658, Training Loss: 17.7938232421875, Validation Loss: 834.1226196289062
# Epoch 1659, Training Loss: 17.776081085205078, Validation Loss: 834.0795288085938
# Epoch 1660, Training Loss: 17.75821304321289, Validation Loss: 834.0401611328125
# Epoch 1661, Training Loss: 17.74053382873535, Validation Loss: 833.9994506835938
# Epoch 1662, Training Loss: 17.72311019897461, Validation Loss: 833.9619140625
# Epoch 1663, Training Loss: 17.70581817626953, Validation Loss: 833.92333984375
# Epoch 1664, Training Loss: 17.68856430053711, Validation Loss: 833.8815307617188
# Epoch 1665, Training Loss: 17.67135238647461, Validation Loss: 833.8367309570312
# Epoch 1666, Training Loss: 17.654308319091797, Validation Loss: 833.7867431640625
# Epoch 1667, Training Loss: 17.637361526489258, Validation Loss: 833.7367553710938
# Epoch 1668, Training Loss: 17.620527267456055, Validation Loss: 833.6817626953125
# Epoch 1669, Training Loss: 17.603878021240234, Validation Loss: 833.6190795898438
# Epoch 1670, Training Loss: 17.58754539489746, Validation Loss: 833.5512084960938
# Epoch 1671, Training Loss: 17.57131576538086, Validation Loss: 833.47509765625
# Epoch 1672, Training Loss: 17.55527687072754, Validation Loss: 833.3917846679688
# Epoch 1673, Training Loss: 17.53929328918457, Validation Loss: 833.3050537109375
# Epoch 1674, Training Loss: 17.523475646972656, Validation Loss: 833.2139892578125
# Epoch 1675, Training Loss: 17.507732391357422, Validation Loss: 833.1173095703125
# Epoch 1676, Training Loss: 17.49216651916504, Validation Loss: 833.0132446289062
# Epoch 1677, Training Loss: 17.476741790771484, Validation Loss: 832.9033203125
# Epoch 1678, Training Loss: 17.46134376525879, Validation Loss: 832.7896728515625
# Epoch 1679, Training Loss: 17.446081161499023, Validation Loss: 832.6712036132812
# Epoch 1680, Training Loss: 17.430999755859375, Validation Loss: 832.5463256835938
# Epoch 1681, Training Loss: 17.416017532348633, Validation Loss: 832.4136352539062
# Epoch 1682, Training Loss: 17.401071548461914, Validation Loss: 832.2728881835938
# Epoch 1683, Training Loss: 17.386173248291016, Validation Loss: 832.12451171875
# Epoch 1684, Training Loss: 17.371292114257812, Validation Loss: 831.9708862304688
# Epoch 1685, Training Loss: 17.356430053710938, Validation Loss: 831.8125610351562
# Epoch 1686, Training Loss: 17.34157371520996, Validation Loss: 831.652099609375
# Epoch 1687, Training Loss: 17.32672119140625, Validation Loss: 831.4907836914062
# Epoch 1688, Training Loss: 17.31191062927246, Validation Loss: 831.3250732421875
# Epoch 1689, Training Loss: 17.297161102294922, Validation Loss: 831.157958984375
# Epoch 1690, Training Loss: 17.28241539001465, Validation Loss: 830.9871215820312
# Epoch 1691, Training Loss: 17.26765251159668, Validation Loss: 830.8154907226562
# Epoch 1692, Training Loss: 17.252899169921875, Validation Loss: 830.64404296875
# Epoch 1693, Training Loss: 17.238170623779297, Validation Loss: 830.47265625
# Epoch 1694, Training Loss: 17.22344398498535, Validation Loss: 830.3012084960938
# Epoch 1695, Training Loss: 17.208744049072266, Validation Loss: 830.1294555664062
# Epoch 1696, Training Loss: 17.194040298461914, Validation Loss: 829.9581909179688
# Epoch 1697, Training Loss: 17.17935562133789, Validation Loss: 829.7891235351562
# Epoch 1698, Training Loss: 17.16469955444336, Validation Loss: 829.6221313476562
# Epoch 1699, Training Loss: 17.15001678466797, Validation Loss: 829.4515991210938
# Epoch 1700, Training Loss: 17.135360717773438, Validation Loss: 829.274658203125
# Epoch 1701, Training Loss: 17.120758056640625, Validation Loss: 829.0942993164062
# Epoch 1702, Training Loss: 17.10614585876465, Validation Loss: 828.9127197265625
# Epoch 1703, Training Loss: 17.091567993164062, Validation Loss: 828.7274780273438
# Epoch 1704, Training Loss: 17.077009201049805, Validation Loss: 828.5398559570312
# Epoch 1705, Training Loss: 17.062471389770508, Validation Loss: 828.3519287109375
# Epoch 1706, Training Loss: 17.04793930053711, Validation Loss: 828.16162109375
# Epoch 1707, Training Loss: 17.033370971679688, Validation Loss: 827.9758911132812
# Epoch 1708, Training Loss: 17.01882553100586, Validation Loss: 827.7972412109375
# Epoch 1709, Training Loss: 17.00429344177246, Validation Loss: 827.6250610351562
# Epoch 1710, Training Loss: 16.989749908447266, Validation Loss: 827.4610595703125
# Epoch 1711, Training Loss: 16.975231170654297, Validation Loss: 827.3054809570312
# Epoch 1712, Training Loss: 16.960718154907227, Validation Loss: 827.1566162109375
# Epoch 1713, Training Loss: 16.946212768554688, Validation Loss: 827.0138549804688
# Epoch 1714, Training Loss: 16.93169593811035, Validation Loss: 826.87646484375
# Epoch 1715, Training Loss: 16.917203903198242, Validation Loss: 826.743408203125
# Epoch 1716, Training Loss: 16.90271759033203, Validation Loss: 826.6146850585938
# Epoch 1717, Training Loss: 16.88822364807129, Validation Loss: 826.4903564453125
# Epoch 1718, Training Loss: 16.873716354370117, Validation Loss: 826.3697509765625
# Epoch 1719, Training Loss: 16.85922622680664, Validation Loss: 826.251708984375
# Epoch 1720, Training Loss: 16.844745635986328, Validation Loss: 826.1353149414062
# Epoch 1721, Training Loss: 16.83025550842285, Validation Loss: 826.0192260742188
# Epoch 1722, Training Loss: 16.815767288208008, Validation Loss: 825.90234375
# Epoch 1723, Training Loss: 16.80129051208496, Validation Loss: 825.7837524414062
# Epoch 1724, Training Loss: 16.786802291870117, Validation Loss: 825.6649780273438
# Epoch 1725, Training Loss: 16.77233123779297, Validation Loss: 825.5454711914062
# Epoch 1726, Training Loss: 16.75786590576172, Validation Loss: 825.4244384765625
# Epoch 1727, Training Loss: 16.743425369262695, Validation Loss: 825.302490234375
# Epoch 1728, Training Loss: 16.728994369506836, Validation Loss: 825.179443359375
# Epoch 1729, Training Loss: 16.714550018310547, Validation Loss: 825.0554809570312
# Epoch 1730, Training Loss: 16.70014190673828, Validation Loss: 824.9298095703125
# Epoch 1731, Training Loss: 16.685747146606445, Validation Loss: 824.8013305664062
# Epoch 1732, Training Loss: 16.671361923217773, Validation Loss: 824.6697387695312
# Epoch 1733, Training Loss: 16.656980514526367, Validation Loss: 824.5347900390625
# Epoch 1734, Training Loss: 16.642627716064453, Validation Loss: 824.3964233398438
# Epoch 1735, Training Loss: 16.628276824951172, Validation Loss: 824.2548828125
# Epoch 1736, Training Loss: 16.61395263671875, Validation Loss: 824.1109008789062
# Epoch 1737, Training Loss: 16.599660873413086, Validation Loss: 823.966796875
# Epoch 1738, Training Loss: 16.585363388061523, Validation Loss: 823.8232421875
# Epoch 1739, Training Loss: 16.571077346801758, Validation Loss: 823.679443359375
# Epoch 1740, Training Loss: 16.55681037902832, Validation Loss: 823.5350341796875
# Epoch 1741, Training Loss: 16.542545318603516, Validation Loss: 823.390380859375
# Epoch 1742, Training Loss: 16.528316497802734, Validation Loss: 823.2442016601562
# Epoch 1743, Training Loss: 16.514142990112305, Validation Loss: 823.0980834960938
# Epoch 1744, Training Loss: 16.49997901916504, Validation Loss: 822.9522094726562
# Epoch 1745, Training Loss: 16.485862731933594, Validation Loss: 822.807861328125
# Epoch 1746, Training Loss: 16.471776962280273, Validation Loss: 822.6669921875
# Epoch 1747, Training Loss: 16.457719802856445, Validation Loss: 822.527099609375
# Epoch 1748, Training Loss: 16.443668365478516, Validation Loss: 822.3895263671875
# Epoch 1749, Training Loss: 16.42963218688965, Validation Loss: 822.2539672851562
# Epoch 1750, Training Loss: 16.415584564208984, Validation Loss: 822.1211547851562
# Epoch 1751, Training Loss: 16.401552200317383, Validation Loss: 821.9901123046875
# Epoch 1752, Training Loss: 16.38751983642578, Validation Loss: 821.86083984375
# Epoch 1753, Training Loss: 16.373567581176758, Validation Loss: 821.7337036132812
# Epoch 1754, Training Loss: 16.35957145690918, Validation Loss: 821.6084594726562
# Epoch 1755, Training Loss: 16.34554672241211, Validation Loss: 821.4822387695312
# Epoch 1756, Training Loss: 16.331575393676758, Validation Loss: 821.3543090820312
# Epoch 1757, Training Loss: 16.317636489868164, Validation Loss: 821.226318359375
# Epoch 1758, Training Loss: 16.30371856689453, Validation Loss: 821.0973510742188
# Epoch 1759, Training Loss: 16.28978157043457, Validation Loss: 820.9672241210938
# Epoch 1760, Training Loss: 16.27587127685547, Validation Loss: 820.8351440429688
# Epoch 1761, Training Loss: 16.261985778808594, Validation Loss: 820.7025146484375
# Epoch 1762, Training Loss: 16.248046875, Validation Loss: 820.5699462890625
# Epoch 1763, Training Loss: 16.234149932861328, Validation Loss: 820.438720703125
# Epoch 1764, Training Loss: 16.220199584960938, Validation Loss: 820.3060913085938
# Epoch 1765, Training Loss: 16.206241607666016, Validation Loss: 820.17041015625
# Epoch 1766, Training Loss: 16.192289352416992, Validation Loss: 820.0314331054688
# Epoch 1767, Training Loss: 16.178327560424805, Validation Loss: 819.8909301757812
# Epoch 1768, Training Loss: 16.164304733276367, Validation Loss: 819.7503662109375
# Epoch 1769, Training Loss: 16.150310516357422, Validation Loss: 819.61083984375
# Epoch 1770, Training Loss: 16.136394500732422, Validation Loss: 819.4724731445312
# Epoch 1771, Training Loss: 16.122425079345703, Validation Loss: 819.3365478515625
# Epoch 1772, Training Loss: 16.108386993408203, Validation Loss: 819.202880859375
# Epoch 1773, Training Loss: 16.09442901611328, Validation Loss: 819.06884765625
# Epoch 1774, Training Loss: 16.080411911010742, Validation Loss: 818.93505859375
# Epoch 1775, Training Loss: 16.066375732421875, Validation Loss: 818.8040161132812
# Epoch 1776, Training Loss: 16.05234146118164, Validation Loss: 818.6751708984375
# Epoch 1777, Training Loss: 16.03828239440918, Validation Loss: 818.5490112304688
# Epoch 1778, Training Loss: 16.02423095703125, Validation Loss: 818.425537109375
# Epoch 1779, Training Loss: 16.010190963745117, Validation Loss: 818.30517578125
# Epoch 1780, Training Loss: 15.996143341064453, Validation Loss: 818.1866455078125
# Epoch 1781, Training Loss: 15.982114791870117, Validation Loss: 818.0703735351562
# Epoch 1782, Training Loss: 15.968151092529297, Validation Loss: 817.9563598632812
# Epoch 1783, Training Loss: 15.954163551330566, Validation Loss: 817.8424072265625
# Epoch 1784, Training Loss: 15.940143585205078, Validation Loss: 817.7266845703125
# Epoch 1785, Training Loss: 15.92621898651123, Validation Loss: 817.6090698242188
# Epoch 1786, Training Loss: 15.912310600280762, Validation Loss: 817.4918212890625
# Epoch 1787, Training Loss: 15.898449897766113, Validation Loss: 817.3748168945312
# Epoch 1788, Training Loss: 15.884588241577148, Validation Loss: 817.2573852539062
# Epoch 1789, Training Loss: 15.8706636428833, Validation Loss: 817.1409912109375
# Epoch 1790, Training Loss: 15.856761932373047, Validation Loss: 817.0266723632812
# Epoch 1791, Training Loss: 15.842918395996094, Validation Loss: 816.9129638671875
# Epoch 1792, Training Loss: 15.829049110412598, Validation Loss: 816.798583984375
# Epoch 1793, Training Loss: 15.815185546875, Validation Loss: 816.68505859375
# Epoch 1794, Training Loss: 15.80131721496582, Validation Loss: 816.5720825195312
# Epoch 1795, Training Loss: 15.787489891052246, Validation Loss: 816.4586181640625
# Epoch 1796, Training Loss: 15.773650169372559, Validation Loss: 816.3473510742188
# Epoch 1797, Training Loss: 15.75981616973877, Validation Loss: 816.241943359375
# Epoch 1798, Training Loss: 15.74601936340332, Validation Loss: 816.1406860351562
# Epoch 1799, Training Loss: 15.732210159301758, Validation Loss: 816.0397338867188
# Epoch 1800, Training Loss: 15.718454360961914, Validation Loss: 815.9384765625

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(num_epochs), train_losses, label='Training Loss')
plt.plot(range(num_epochs), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
def evaluate_model(model, features, labels):
    model.eval()
    with torch.no_grad():
        outputs = model(features)
        mse_loss = criterion(outputs, labels)
        mae_loss = torch.mean(torch.abs(outputs - labels))
        return outputs, mse_loss.item(), mae_loss.item()

# %%
train_outputs, train_mse, train_mae = evaluate_model(model, train_features, train_labels)
print(f"Training MSE Loss: {train_mse}, Training MAE: {train_mae}")
# Out:
# Training MSE Loss: 15.704679489135742, Training MAE: 3.085864543914795

# %%
test_outputs, test_mse, test_mae = evaluate_model(model, val_features, val_labels)
print(f"Testing MSE Loss: {test_mse}, Testing MAE: {test_mae}")
# Out:
# Testing MSE Loss: 815.9384765625, Testing MAE: 23.218307495117188

# %%
plt.figure(figsize=(12, 8))
plt.plot(train_labels.numpy()[:, 0], label='Actual Train Labels', color='blue', alpha=0.6)
plt.plot(train_outputs.numpy()[:, 0], label='Predicted Train Labels', color='orange', alpha=0.6)
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Sample')
plt.ylabel('Adjusted Close Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(val_labels.numpy()[:, 0], label='Actual Test Labels', color='blue', alpha=0.6)
plt.plot(test_outputs.numpy()[:, 0], label='Predicted Test Labels', color='orange', alpha=0.6)
plt.title('Testing Data: Actual vs Predicted')
plt.xlabel('Sample')
plt.ylabel('Adjusted Close Price')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming `train_labels` and `train_predictions` are the actual and predicted prices for the training data
# and `val_labels` and `val_predictions` are the actual and predicted prices for the validation data
# Convert predictions to numpy arrays for plotting, if necessary
train_predictions = model(train_features).detach().numpy()
val_predictions = model(val_features).detach().numpy()

# Convert labels to numpy arrays if they are still tensors
train_labels_np = train_labels.numpy()
val_labels_np = val_labels.numpy()

# %%
plt.figure(figsize=(14, 7))
plt.plot(train_labels_np, label="Actual Train Prices", color="blue", linestyle="dashed")
plt.plot(train_predictions, label="Predicted Train Prices", color="red")
plt.title("Training Data: Actual vs Predicted Adjusted Close Price")
plt.xlabel("Days")
plt.ylabel("Adjusted Close Price")
plt.legend()
plt.show()

# %%
predicted = pd.DataFrame(val_predictions)

# %%
actual = pd.DataFrame(val_labels_np)

# %%
compare = pd.concat([actual,predicted],axis=1)

# %%
compare
# Out:
#               0           0
# 0    146.801010  139.805893
# 1    148.113739  143.784058
# 2    147.737350  140.629761
# 3    147.113113  141.522308
# 4    144.763000  136.658447
# ..          ...         ...
# 725  163.369995  161.649017
# 726  162.949997  163.304291
# 727  163.919998  164.469376
# 728  164.229996  166.343231
# 729  165.860001  170.635727
#
# [730 rows x 2 columns]

# %%
compare.head(20)
# Out:
#              0           0
# 0   108.206650  103.688202
# 1   152.885300  176.899704
# 2   103.345146   98.314232
# 3   117.743011  105.142464
# 4    77.990822   71.440010
# 5   160.114716  163.316193
# 6   123.966217  123.347198
# 7   163.340775  167.841095
# 8    90.506744   90.336761
# 9    72.700417   80.621559
# 10  150.391174  143.889999
# 11  165.841064  118.876587
# 12  114.362480  117.304398
# 13  113.074562   63.798862
# 14  153.502747  147.908447
# 15  116.151779  122.728279
# 16  131.821350   71.162476
# 17  154.959442  144.446976
# 18  107.909332   96.937065
# 19  116.305611  107.485588
